# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key 
import time
from datetime import datetime

# %%
# Create a set of 2000 random latitude and longitude combinations.

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Pair the values
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.

print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | talaya
# Processing Record 3 of Set 1 | aksu
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | port keats
# Processing Record 7 of Set 1 | pilar
# Processing Record 8 of Set 1 | hualmay
# Processing Record 9 of Set 1 | grafton
# Processing Record 10 of Set 1 | mnogovershinnyy
# Processing Record 11 of Set 1 | hithadhoo
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | east london
# Processing Record 16 of Set 1 | qaanaaq
# Processing Record 17 of Set 1 | harrison
# Processing Record 18 of Set 1 | hurghada
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | upernavik
# Processing Record 23 of Set 1 | guerrero negro
# Processing Record 24 of Set 1 | tkvarcheli
# City not found. Skipping...
# Processing Record 25 of Set 1 | dongsheng
# Processing Record 26 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 27 of Set 1 | songjianghe
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | new norfolk
# Processing Record 33 of Set 1 | huaral
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 1 | port elizabeth
# Processing Record 37 of Set 1 | polovinnoye
# Processing Record 38 of Set 1 | vao
# Processing Record 39 of Set 1 | yar-sale
# Processing Record 40 of Set 1 | vila velha
# Processing Record 41 of Set 1 | pisco
# Processing Record 42 of Set 1 | dwarka
# Processing Record 43 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 1 | ribeira grande
# Processing Record 45 of Set 1 | yellowknife
# Processing Record 46 of Set 1 | zhigansk
# Processing Record 47 of Set 1 | praia
# Processing Record 48 of Set 1 | piatra soimului
# Processing Record 49 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | vestmanna
# Processing Record 2 of Set 2 | klaksvik
# Processing Record 3 of Set 2 | vardo
# Processing Record 4 of Set 2 | belmonte
# Processing Record 5 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 2 | singapore
# Processing Record 7 of Set 2 | norman wells
# Processing Record 8 of Set 2 | vaini
# Processing Record 9 of Set 2 | central point
# Processing Record 10 of Set 2 | thompson
# Processing Record 11 of Set 2 | faanui
# Processing Record 12 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 2 | puerto ayora
# Processing Record 14 of Set 2 | atuona
# Processing Record 15 of Set 2 | aksarka
# Processing Record 16 of Set 2 | arraial do cabo
# Processing Record 17 of Set 2 | werda
# Processing Record 18 of Set 2 | arys
# Processing Record 19 of Set 2 | airai
# Processing Record 20 of Set 2 | avarua
# Processing Record 21 of Set 2 | salalah
# Processing Record 22 of Set 2 | flores
# Processing Record 23 of Set 2 | mar del plata
# Processing Record 24 of Set 2 | vitim
# Processing Record 25 of Set 2 | ostrovnoy
# Processing Record 26 of Set 2 | lompoc
# Processing Record 27 of Set 2 | oulainen
# Processing Record 28 of Set 2 | zheleznodorozhnyy
# Processing Record 29 of Set 2 | ponta delgada
# Processing Record 30 of Set 2 | massaguet
# Processing Record 31 of Set 2 | solotcha
# Processing Record 32 of Set 2 | yandyki
# Processing Record 33 of Set 2 | saint-philippe
# Processing Record 34 of Set 2 | provideniya
# Processing Record 35 of Set 2 | znamenka
# Processing Record 36 of Set 2 | fairbanks
# Processing Record 37 of Set 2 | harper
# Processing Record 38 of Set 2 | mahebourg
# Processing Record 39 of Set 2 | kruisfontein
# Processing Record 40 of Set 2 | bredasdorp
# Processing Record 41 of Set 2 | barrow
# Processing Record 42 of Set 2 | krasnaya zarya
# Processing Record 43 of Set 2 | hasaki
# Processing Record 44 of Set 2 | castro
# Processing Record 45 of Set 2 | yaan
# Processing Record 46 of Set 2 | beidao
# Processing Record 47 of Set 2 | mayo
# Processing Record 48 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 49 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 2 | esperance
# Processing Record 1 of Set 3 | clyde river
# Processing Record 2 of Set 3 | minas
# Processing Record 3 of Set 3 | faya
# Processing Record 4 of Set 3 | victoria
# Processing Record 5 of Set 3 | maridi
# Processing Record 6 of Set 3 | talcahuano
# Processing Record 7 of Set 3 | acarau
# Processing Record 8 of Set 3 | nanortalik
# Processing Record 9 of Set 3 | north bend
# Processing Record 10 of Set 3 | iqaluit
# Processing Record 11 of Set 3 | pozo colorado
# Processing Record 12 of Set 3 | moree
# Processing Record 13 of Set 3 | scarborough
# Processing Record 14 of Set 3 | deputatskiy
# Processing Record 15 of Set 3 | acari
# Processing Record 16 of Set 3 | sao filipe
# Processing Record 17 of Set 3 | dalbandin
# Processing Record 18 of Set 3 | masvingo
# Processing Record 19 of Set 3 | hobart
# Processing Record 20 of Set 3 | kapaa
# Processing Record 21 of Set 3 | ahuimanu
# Processing Record 22 of Set 3 | pevek
# Processing Record 23 of Set 3 | santa rosa
# Processing Record 24 of Set 3 | ventspils
# Processing Record 25 of Set 3 | itoman
# Processing Record 26 of Set 3 | bandarbeyla
# Processing Record 27 of Set 3 | narsaq
# Processing Record 28 of Set 3 | tiksi
# Processing Record 29 of Set 3 | caravelas
# Processing Record 30 of Set 3 | nadym
# Processing Record 31 of Set 3 | bolshaya rechka
# Processing Record 32 of Set 3 | guarapari
# Processing Record 33 of Set 3 | butaritari
# Processing Record 34 of Set 3 | aklavik
# Processing Record 35 of Set 3 | otradnaya
# Processing Record 36 of Set 3 | san quintin
# Processing Record 37 of Set 3 | mandan
# Processing Record 38 of Set 3 | sukhumi
# Processing Record 39 of Set 3 | prince rupert
# Processing Record 40 of Set 3 | lagoa
# Processing Record 41 of Set 3 | fortuna
# Processing Record 42 of Set 3 | rundu
# Processing Record 43 of Set 3 | isangel
# Processing Record 44 of Set 3 | sept-iles
# Processing Record 45 of Set 3 | cidreira
# Processing Record 46 of Set 3 | mayumba
# Processing Record 47 of Set 3 | payo
# Processing Record 48 of Set 3 | pontes e lacerda
# Processing Record 49 of Set 3 | san felipe
# Processing Record 50 of Set 3 | padang
# Processing Record 1 of Set 4 | saskylakh
# Processing Record 2 of Set 4 | amuntai
# Processing Record 3 of Set 4 | belaya gora
# Processing Record 4 of Set 4 | kushima
# Processing Record 5 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 4 | solana beach
# Processing Record 7 of Set 4 | nikolskoye
# Processing Record 8 of Set 4 | chicama
# Processing Record 9 of Set 4 | colac
# Processing Record 10 of Set 4 | turukhansk
# Processing Record 11 of Set 4 | touros
# Processing Record 12 of Set 4 | lebu
# Processing Record 13 of Set 4 | coahuayana
# Processing Record 14 of Set 4 | leningradskiy
# Processing Record 15 of Set 4 | egvekinot
# Processing Record 16 of Set 4 | dunedin
# Processing Record 17 of Set 4 | vuktyl
# Processing Record 18 of Set 4 | abu zabad
# Processing Record 19 of Set 4 | port alfred
# Processing Record 20 of Set 4 | preobrazheniye
# Processing Record 21 of Set 4 | georgetown
# Processing Record 22 of Set 4 | vila do maio
# Processing Record 23 of Set 4 | mukhen
# Processing Record 24 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 4 | saint-francois
# Processing Record 26 of Set 4 | kodiak
# Processing Record 27 of Set 4 | ixtapa
# Processing Record 28 of Set 4 | khatanga
# Processing Record 29 of Set 4 | dikson
# Processing Record 30 of Set 4 | solnechnyy
# Processing Record 31 of Set 4 | huazolotitlan
# City not found. Skipping...
# Processing Record 32 of Set 4 | parakou
# Processing Record 33 of Set 4 | qaqortoq
# Processing Record 34 of Set 4 | itarema
# Processing Record 35 of Set 4 | dekoa
# City not found. Skipping...
# Processing Record 36 of Set 4 | souillac
# Processing Record 37 of Set 4 | cockburn town
# Processing Record 38 of Set 4 | puerto madryn
# Processing Record 39 of Set 4 | tilichiki
# Processing Record 40 of Set 4 | katsuura
# Processing Record 41 of Set 4 | abu samrah
# Processing Record 42 of Set 4 | henties bay
# Processing Record 43 of Set 4 | shingu
# Processing Record 44 of Set 4 | ntchisi
# Processing Record 45 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 4 | caledon
# Processing Record 47 of Set 4 | aranos
# Processing Record 48 of Set 4 | biak
# Processing Record 49 of Set 4 | saldanha
# Processing Record 50 of Set 4 | slave lake
# Processing Record 1 of Set 5 | acapulco
# Processing Record 2 of Set 5 | chornukhy
# Processing Record 3 of Set 5 | lebowakgomo
# Processing Record 4 of Set 5 | severo-kurilsk
# Processing Record 5 of Set 5 | cherskiy
# Processing Record 6 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 7 of Set 5 | puerto escondido
# Processing Record 8 of Set 5 | westport
# Processing Record 9 of Set 5 | bengkulu
# Processing Record 10 of Set 5 | ust-maya
# Processing Record 11 of Set 5 | bathsheba
# Processing Record 12 of Set 5 | north platte
# Processing Record 13 of Set 5 | alappuzha
# Processing Record 14 of Set 5 | gat
# Processing Record 15 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 5 | saint-jean-de-maurienne
# Processing Record 17 of Set 5 | nome
# Processing Record 18 of Set 5 | banmo
# City not found. Skipping...
# Processing Record 19 of Set 5 | stokmarknes
# Processing Record 20 of Set 5 | poum
# Processing Record 21 of Set 5 | valparaiso
# Processing Record 22 of Set 5 | middle island
# Processing Record 23 of Set 5 | gopalpur
# Processing Record 24 of Set 5 | kavieng
# Processing Record 25 of Set 5 | bonavista
# Processing Record 26 of Set 5 | vallenar
# Processing Record 27 of Set 5 | strelka
# Processing Record 28 of Set 5 | neiafu
# Processing Record 29 of Set 5 | luganville
# Processing Record 30 of Set 5 | torbay
# Processing Record 31 of Set 5 | castletown
# Processing Record 32 of Set 5 | laguna
# Processing Record 33 of Set 5 | mezhdurechensk
# Processing Record 34 of Set 5 | sorong
# Processing Record 35 of Set 5 | chatham
# Processing Record 36 of Set 5 | scottsburgh
# City not found. Skipping...
# Processing Record 37 of Set 5 | manoel urbano
# Processing Record 38 of Set 5 | pacific grove
# Processing Record 39 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 40 of Set 5 | xichang
# Processing Record 41 of Set 5 | lorengau
# Processing Record 42 of Set 5 | ostrovskoye
# Processing Record 43 of Set 5 | bolshiye berezniki
# City not found. Skipping...
# Processing Record 44 of Set 5 | kiama
# Processing Record 45 of Set 5 | nioro
# Processing Record 46 of Set 5 | bethel
# Processing Record 47 of Set 5 | ilulissat
# Processing Record 48 of Set 5 | keflavik
# Processing Record 49 of Set 5 | hirara
# Processing Record 50 of Set 5 | ko samui
# Processing Record 1 of Set 6 | imeni zhelyabova
# Processing Record 2 of Set 6 | bereda
# Processing Record 3 of Set 6 | codrington
# Processing Record 4 of Set 6 | timmins
# Processing Record 5 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 6 | honiara
# Processing Record 7 of Set 6 | grindavik
# Processing Record 8 of Set 6 | ketchikan
# Processing Record 9 of Set 6 | nantucket
# Processing Record 10 of Set 6 | general pico
# Processing Record 11 of Set 6 | honolulu
# Processing Record 12 of Set 6 | santa cruz
# Processing Record 13 of Set 6 | kitui
# Processing Record 14 of Set 6 | axim
# Processing Record 15 of Set 6 | nichinan
# Processing Record 16 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 6 | worland
# Processing Record 18 of Set 6 | tasiilaq
# Processing Record 19 of Set 6 | mana
# Processing Record 20 of Set 6 | nahuala
# Processing Record 21 of Set 6 | ingham
# Processing Record 22 of Set 6 | chumikan
# Processing Record 23 of Set 6 | baykit
# Processing Record 24 of Set 6 | armacao dos buzios
# City not found. Skipping...
# Processing Record 25 of Set 6 | hambantota
# Processing Record 26 of Set 6 | sao miguel do araguaia
# Processing Record 27 of Set 6 | mucurici
# Processing Record 28 of Set 6 | stoyba
# City not found. Skipping...
# Processing Record 29 of Set 6 | vanavara
# Processing Record 30 of Set 6 | dakar
# Processing Record 31 of Set 6 | muros
# Processing Record 32 of Set 6 | lesnoy
# Processing Record 33 of Set 6 | listica
# City not found. Skipping...
# Processing Record 34 of Set 6 | nchelenge
# Processing Record 35 of Set 6 | tunduru
# City not found. Skipping...
# Processing Record 36 of Set 6 | waingapu
# Processing Record 37 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 38 of Set 6 | karakendzha
# City not found. Skipping...
# Processing Record 39 of Set 6 | meiganga
# Processing Record 40 of Set 6 | tuy hoa
# Processing Record 41 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 6 | epe
# Processing Record 43 of Set 6 | yerbogachen
# Processing Record 44 of Set 6 | kitgum
# Processing Record 45 of Set 6 | springbok
# Processing Record 46 of Set 6 | labrea
# Processing Record 47 of Set 6 | clearwater
# Processing Record 48 of Set 6 | ust-nera
# Processing Record 49 of Set 6 | kirakira
# Processing Record 50 of Set 6 | stromness
# Processing Record 1 of Set 7 | mount isa
# Processing Record 2 of Set 7 | mokhsogollokh
# Processing Record 3 of Set 7 | taoudenni
# Processing Record 4 of Set 7 | the valley
# Processing Record 5 of Set 7 | kaeo
# Processing Record 6 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 7 | haines junction
# Processing Record 8 of Set 7 | karasjok
# Processing Record 9 of Set 7 | mahroni
# Processing Record 10 of Set 7 | am timan
# Processing Record 11 of Set 7 | nouakchott
# Processing Record 12 of Set 7 | te anau
# Processing Record 13 of Set 7 | carnarvon
# Processing Record 14 of Set 7 | dabhoi
# Processing Record 15 of Set 7 | jalu
# Processing Record 16 of Set 7 | olenegorsk
# Processing Record 17 of Set 7 | krasnyy oktyabr
# Processing Record 18 of Set 7 | san cristobal
# Processing Record 19 of Set 7 | brigantine
# Processing Record 20 of Set 7 | quelimane
# Processing Record 21 of Set 7 | cabo san lucas
# Processing Record 22 of Set 7 | sao felix do xingu
# Processing Record 23 of Set 7 | wasilla
# Processing Record 24 of Set 7 | balabac
# Processing Record 25 of Set 7 | urumqi
# Processing Record 26 of Set 7 | nuuk
# Processing Record 27 of Set 7 | northam
# Processing Record 28 of Set 7 | ponta do sol
# Processing Record 29 of Set 7 | prainha
# Processing Record 30 of Set 7 | phan thiet
# Processing Record 31 of Set 7 | wucheng
# Processing Record 32 of Set 7 | hervey bay
# Processing Record 33 of Set 7 | great yarmouth
# Processing Record 34 of Set 7 | komsomolskiy
# Processing Record 35 of Set 7 | elizabeth city
# Processing Record 36 of Set 7 | hofn
# Processing Record 37 of Set 7 | namie
# Processing Record 38 of Set 7 | manzil tamim
# City not found. Skipping...
# Processing Record 39 of Set 7 | saint-georges
# Processing Record 40 of Set 7 | vestmannaeyjar
# Processing Record 41 of Set 7 | tuatapere
# Processing Record 42 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 43 of Set 7 | port-cartier
# Processing Record 44 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 45 of Set 7 | ayan
# Processing Record 46 of Set 7 | tra vinh
# Processing Record 47 of Set 7 | aripuana
# Processing Record 48 of Set 7 | nalut
# Processing Record 49 of Set 7 | pimentel
# Processing Record 50 of Set 7 | orasje
# Processing Record 1 of Set 8 | los llanos de aridane
# Processing Record 2 of Set 8 | blagodatnoye
# Processing Record 3 of Set 8 | cavarzere
# Processing Record 4 of Set 8 | muktagachha
# City not found. Skipping...
# Processing Record 5 of Set 8 | megion
# Processing Record 6 of Set 8 | forest
# Processing Record 7 of Set 8 | gamba
# Processing Record 8 of Set 8 | lavrentiya
# Processing Record 9 of Set 8 | abha
# Processing Record 10 of Set 8 | longyearbyen
# Processing Record 11 of Set 8 | elko
# Processing Record 12 of Set 8 | lang suan
# Processing Record 13 of Set 8 | jaromerice nad rokytnou
# Processing Record 14 of Set 8 | mount gambier
# Processing Record 15 of Set 8 | marawi
# Processing Record 16 of Set 8 | plettenberg bay
# Processing Record 17 of Set 8 | tahta
# Processing Record 18 of Set 8 | kenai
# Processing Record 19 of Set 8 | san lorenzo
# Processing Record 20 of Set 8 | luderitz
# Processing Record 21 of Set 8 | ukiah
# Processing Record 22 of Set 8 | sobolevo
# Processing Record 23 of Set 8 | awbari
# Processing Record 24 of Set 8 | colares
# Processing Record 25 of Set 8 | atambua
# Processing Record 26 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 27 of Set 8 | kaitangata
# Processing Record 28 of Set 8 | bambous virieux
# Processing Record 29 of Set 8 | mitsamiouli
# Processing Record 30 of Set 8 | tiznit
# Processing Record 31 of Set 8 | vila franca do campo
# Processing Record 32 of Set 8 | bardsir
# Processing Record 33 of Set 8 | waipawa
# Processing Record 34 of Set 8 | saint anthony
# Processing Record 35 of Set 8 | tay ninh
# Processing Record 36 of Set 8 | chuy
# Processing Record 37 of Set 8 | bilibino
# Processing Record 38 of Set 8 | akyab
# Processing Record 39 of Set 8 | guaymas
# Processing Record 40 of Set 8 | kununurra
# Processing Record 41 of Set 8 | sitka
# Processing Record 42 of Set 8 | kemi
# Processing Record 43 of Set 8 | sao joao da barra
# Processing Record 44 of Set 8 | mwadui
# Processing Record 45 of Set 8 | tuktoyaktuk
# Processing Record 46 of Set 8 | erdenet
# Processing Record 47 of Set 8 | cap-aux-meules
# Processing Record 48 of Set 8 | mollendo
# Processing Record 49 of Set 8 | tual
# Processing Record 50 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 9 | kavaratti
# Processing Record 2 of Set 9 | korla
# Processing Record 3 of Set 9 | karpogory
# Processing Record 4 of Set 9 | port moresby
# Processing Record 5 of Set 9 | kysyl-syr
# Processing Record 6 of Set 9 | bunesti
# Processing Record 7 of Set 9 | college
# Processing Record 8 of Set 9 | road town
# Processing Record 9 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 10 of Set 9 | carmen
# Processing Record 11 of Set 9 | jadu
# Processing Record 12 of Set 9 | bambanglipuro
# Processing Record 13 of Set 9 | kahului
# Processing Record 14 of Set 9 | teya
# Processing Record 15 of Set 9 | ngunguru
# Processing Record 16 of Set 9 | vostok
# Processing Record 17 of Set 9 | pangai
# Processing Record 18 of Set 9 | san-pedro
# Processing Record 19 of Set 9 | woodward
# Processing Record 20 of Set 9 | nabire
# Processing Record 21 of Set 9 | labuhan
# Processing Record 22 of Set 9 | sirajganj
# Processing Record 23 of Set 9 | porto novo
# Processing Record 24 of Set 9 | fort nelson
# Processing Record 25 of Set 9 | russellville
# Processing Record 26 of Set 9 | evensk
# Processing Record 27 of Set 9 | sakhon nakhon
# Processing Record 28 of Set 9 | thinadhoo
# Processing Record 29 of Set 9 | olinda
# Processing Record 30 of Set 9 | kungurtug
# Processing Record 31 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 32 of Set 9 | korhogo
# Processing Record 33 of Set 9 | uttiramerur
# Processing Record 34 of Set 9 | saint-augustin
# Processing Record 35 of Set 9 | chokurdakh
# Processing Record 36 of Set 9 | port hardy
# Processing Record 37 of Set 9 | tupi paulista
# Processing Record 38 of Set 9 | shibarghan
# City not found. Skipping...
# Processing Record 39 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 40 of Set 9 | biltine
# Processing Record 41 of Set 9 | san juan
# Processing Record 42 of Set 9 | gondanglegi
# Processing Record 43 of Set 9 | nha trang
# Processing Record 44 of Set 9 | toungoo
# City not found. Skipping...
# Processing Record 45 of Set 9 | catuday
# Processing Record 46 of Set 9 | weingarten
# Processing Record 47 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 48 of Set 9 | bosaso
# Processing Record 49 of Set 9 | cine
# Processing Record 50 of Set 9 | saint george
# Processing Record 1 of Set 10 | shimoda
# Processing Record 2 of Set 10 | aswan
# Processing Record 3 of Set 10 | puerto del rosario
# Processing Record 4 of Set 10 | oranjestad
# Processing Record 5 of Set 10 | khani
# Processing Record 6 of Set 10 | coxim
# Processing Record 7 of Set 10 | half moon bay
# Processing Record 8 of Set 10 | juye
# Processing Record 9 of Set 10 | motril
# Processing Record 10 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 11 of Set 10 | bermeo
# Processing Record 12 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 13 of Set 10 | kannauj
# Processing Record 14 of Set 10 | tongliao
# Processing Record 15 of Set 10 | belyy yar
# Processing Record 16 of Set 10 | moranbah
# Processing Record 17 of Set 10 | kalianget
# Processing Record 18 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 19 of Set 10 | niimi
# Processing Record 20 of Set 10 | yanam
# Processing Record 21 of Set 10 | obluche
# City not found. Skipping...
# Processing Record 22 of Set 10 | tamandare
# Processing Record 23 of Set 10 | port-de-paix
# City not found. Skipping...
# Processing Record 24 of Set 10 | flinders
# Processing Record 25 of Set 10 | mingshui
# Processing Record 26 of Set 10 | general roca
# Processing Record 27 of Set 10 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 28 of Set 10 | kunya
# Processing Record 29 of Set 10 | carballo
# Processing Record 30 of Set 10 | verkhnevilyuysk
# Processing Record 31 of Set 10 | massakory
# Processing Record 32 of Set 10 | djibo
# Processing Record 33 of Set 10 | carolina
# Processing Record 34 of Set 10 | ryotsu
# Processing Record 35 of Set 10 | dodge city
# Processing Record 36 of Set 10 | bahia blanca
# Processing Record 37 of Set 10 | rodrigues alves
# Processing Record 38 of Set 10 | srandakan
# Processing Record 39 of Set 10 | rawson
# Processing Record 40 of Set 10 | chilac
# City not found. Skipping...
# Processing Record 41 of Set 10 | peno
# Processing Record 42 of Set 10 | san luis
# Processing Record 43 of Set 10 | mastic beach
# Processing Record 44 of Set 10 | twin falls
# Processing Record 45 of Set 10 | grasse
# Processing Record 46 of Set 10 | edson
# Processing Record 47 of Set 10 | maple creek
# Processing Record 48 of Set 10 | piacabucu
# Processing Record 49 of Set 10 | winnemucca
# Processing Record 50 of Set 10 | namibe
# Processing Record 1 of Set 11 | sorland
# Processing Record 2 of Set 11 | powell river
# Processing Record 3 of Set 11 | riyadh
# Processing Record 4 of Set 11 | monitos
# Processing Record 5 of Set 11 | tawzar
# City not found. Skipping...
# Processing Record 6 of Set 11 | bagotville
# Processing Record 7 of Set 11 | kon tum
# Processing Record 8 of Set 11 | songadh
# Processing Record 9 of Set 11 | cessnock
# Processing Record 10 of Set 11 | teahupoo
# Processing Record 11 of Set 11 | zeya
# Processing Record 12 of Set 11 | jiuquan
# Processing Record 13 of Set 11 | emba
# Processing Record 14 of Set 11 | huarmey
# Processing Record 15 of Set 11 | inhambane
# Processing Record 16 of Set 11 | sergeyevka
# Processing Record 17 of Set 11 | yeniseysk
# Processing Record 18 of Set 11 | kargasok
# Processing Record 19 of Set 11 | agadez
# Processing Record 20 of Set 11 | vaovai
# City not found. Skipping...
# Processing Record 21 of Set 11 | matadi
# Processing Record 22 of Set 11 | salinopolis
# Processing Record 23 of Set 11 | krasnoselkup
# Processing Record 24 of Set 11 | freeport
# Processing Record 25 of Set 11 | idrija
# Processing Record 26 of Set 11 | thiruvananthapuram
# Processing Record 27 of Set 11 | maniitsoq
# Processing Record 28 of Set 11 | havre
# Processing Record 29 of Set 11 | talnakh
# Processing Record 30 of Set 11 | tessalit
# Processing Record 31 of Set 11 | seoul
# Processing Record 32 of Set 11 | katobu
# Processing Record 33 of Set 11 | bradford
# Processing Record 34 of Set 11 | oktyabrskoye
# Processing Record 35 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 36 of Set 11 | bac lieu
# Processing Record 37 of Set 11 | lensk
# Processing Record 38 of Set 11 | fort-shevchenko
# Processing Record 39 of Set 11 | beloha
# Processing Record 40 of Set 11 | launceston
# Processing Record 41 of Set 11 | pasaje
# Processing Record 42 of Set 11 | bone
# Processing Record 43 of Set 11 | menongue
# Processing Record 44 of Set 11 | barkly west
# Processing Record 45 of Set 11 | maiduguri
# Processing Record 46 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 11 | apatity
# Processing Record 48 of Set 11 | viransehir
# Processing Record 49 of Set 11 | chipinge
# Processing Record 50 of Set 11 | balagansk
# Processing Record 1 of Set 12 | kiruna
# Processing Record 2 of Set 12 | bartica
# Processing Record 3 of Set 12 | hobyo
# Processing Record 4 of Set 12 | ulaanbaatar
# Processing Record 5 of Set 12 | tukrah
# Processing Record 6 of Set 12 | zitose
# Processing Record 7 of Set 12 | angoche
# Processing Record 8 of Set 12 | necochea
# Processing Record 9 of Set 12 | la ronge
# Processing Record 10 of Set 12 | vincennes
# Processing Record 11 of Set 12 | raipur
# Processing Record 12 of Set 12 | arvika
# Processing Record 13 of Set 12 | port macquarie
# Processing Record 14 of Set 12 | wad rawah
# Processing Record 15 of Set 12 | roald
# Processing Record 16 of Set 12 | bridlington
# Processing Record 17 of Set 12 | kasungu
# Processing Record 18 of Set 12 | lashio
# Processing Record 19 of Set 12 | leh
# Processing Record 20 of Set 12 | banjar
# Processing Record 21 of Set 12 | ozark
# Processing Record 22 of Set 12 | santa vitoria do palmar
# Processing Record 23 of Set 12 | fez
# Processing Record 24 of Set 12 | general salgado
# Processing Record 25 of Set 12 | khilok
# Processing Record 26 of Set 12 | lata
# Processing Record 27 of Set 12 | shu
# Processing Record 28 of Set 12 | boras
# Processing Record 29 of Set 12 | geraldton
# Processing Record 30 of Set 12 | tahe
# Processing Record 31 of Set 12 | ambilobe
# Processing Record 32 of Set 12 | mawlaik
# Processing Record 33 of Set 12 | semiletka
# Processing Record 34 of Set 12 | ulladulla
# Processing Record 35 of Set 12 | hamilton
# Processing Record 36 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 12 | san clemente
# Processing Record 38 of Set 12 | gulabpura
# Processing Record 39 of Set 12 | tombouctou
# Processing Record 40 of Set 12 | petrodvorets
# Processing Record 41 of Set 12 | pavlovsk
# Processing Record 42 of Set 12 | karratha
# Processing Record 43 of Set 12 | roebourne
# Processing Record 44 of Set 12 | bekhtery
# Processing Record 45 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 46 of Set 12 | buckeye
# Processing Record 47 of Set 12 | sovetskiy
# Processing Record 48 of Set 12 | nurmijarvi
# Processing Record 49 of Set 12 | uzhur
# Processing Record 50 of Set 12 | kupang
# Processing Record 1 of Set 13 | progreso
# Processing Record 2 of Set 13 | hidalgo
# Processing Record 3 of Set 13 | ekhabi
# Processing Record 4 of Set 13 | minbu
# Processing Record 5 of Set 13 | saint-pierre
# Processing Record 6 of Set 13 | tarime
# Processing Record 7 of Set 13 | stepnogorsk
# Processing Record 8 of Set 13 | mtambile
# Processing Record 9 of Set 13 | fukue
# Processing Record 10 of Set 13 | port hedland
# Processing Record 11 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 13 | srednekolymsk
# Processing Record 13 of Set 13 | ekibastuz
# Processing Record 14 of Set 13 | guicheng
# City not found. Skipping...
# Processing Record 15 of Set 13 | pietermaritzburg
# Processing Record 16 of Set 13 | haapu
# City not found. Skipping...
# Processing Record 17 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 18 of Set 13 | arecibo
# Processing Record 19 of Set 13 | santiago
# Processing Record 20 of Set 13 | kasongo-lunda
# Processing Record 21 of Set 13 | burica
# City not found. Skipping...
# Processing Record 22 of Set 13 | lakewood
# Processing Record 23 of Set 13 | jasper
# Processing Record 24 of Set 13 | luwuk
# Processing Record 25 of Set 13 | abu dhabi
# Processing Record 26 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 13 | jiujiang
# Processing Record 28 of Set 13 | trojan
# Processing Record 29 of Set 13 | ostrov
# Processing Record 30 of Set 13 | husavik
# Processing Record 31 of Set 13 | grand gaube
# Processing Record 32 of Set 13 | kokopo
# Processing Record 33 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 34 of Set 13 | safford
# Processing Record 35 of Set 13 | aksha
# Processing Record 36 of Set 13 | paamiut
# Processing Record 37 of Set 13 | luang prabang
# Processing Record 38 of Set 13 | les cayes
# Processing Record 39 of Set 13 | portland
# Processing Record 40 of Set 13 | sungaipenuh
# Processing Record 41 of Set 13 | randolph
# Processing Record 42 of Set 13 | lubao
# Processing Record 43 of Set 13 | krasnogorsk
# Processing Record 44 of Set 13 | santa marta
# Processing Record 45 of Set 13 | mago
# Processing Record 46 of Set 13 | saint-raymond
# Processing Record 47 of Set 13 | tartki
# City not found. Skipping...
# Processing Record 48 of Set 13 | kirensk
# Processing Record 49 of Set 13 | maloshuyka
# City not found. Skipping...
# Processing Record 50 of Set 13 | zhanakorgan
# Processing Record 1 of Set 14 | whitehorse
# Processing Record 2 of Set 14 | antalaha
# Processing Record 3 of Set 14 | yumen
# Processing Record 4 of Set 14 | denham springs
# Processing Record 5 of Set 14 | santa lucia
# Processing Record 6 of Set 14 | stolin
# Processing Record 7 of Set 14 | coffs harbour
# Processing Record 8 of Set 14 | tadine
# Processing Record 9 of Set 14 | cesis
# Processing Record 10 of Set 14 | isla mujeres
# Processing Record 11 of Set 14 | boma
# Processing Record 12 of Set 14 | chone
# Processing Record 13 of Set 14 | kurilsk
# Processing Record 14 of Set 14 | agua buena
# Processing Record 15 of Set 14 | reyes
# Processing Record 16 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 17 of Set 14 | erzincan
# Processing Record 18 of Set 14 | port blair
# Processing Record 19 of Set 14 | morshyn
# Processing Record 20 of Set 14 | gobabis
# Processing Record 21 of Set 14 | atar
# Processing Record 22 of Set 14 | mackay
# Processing Record 23 of Set 14 | coquimbo
# Processing Record 24 of Set 14 | klyuchevskiy
# Processing Record 25 of Set 14 | show low
# Processing Record 26 of Set 14 | mpulungu
# Processing Record 27 of Set 14 | sibolga
# Processing Record 28 of Set 14 | taltal
# Processing Record 29 of Set 14 | lafiagi
# Processing Record 30 of Set 14 | kidal
# Processing Record 31 of Set 14 | tautira
# Processing Record 32 of Set 14 | manzhouli
# Processing Record 33 of Set 14 | havoysund
# Processing Record 34 of Set 14 | baghdad
# Processing Record 35 of Set 14 | nelson bay
# Processing Record 36 of Set 14 | constitucion
# Processing Record 37 of Set 14 | porto velho
# Processing Record 38 of Set 14 | ostersund
# Processing Record 39 of Set 14 | kailua
# Processing Record 40 of Set 14 | tyret pervaya
# Processing Record 41 of Set 14 | novosergiyevka
# Processing Record 42 of Set 14 | asau
# Processing Record 43 of Set 14 | ust-omchug
# Processing Record 44 of Set 14 | kathmandu
# Processing Record 45 of Set 14 | denpasar
# Processing Record 46 of Set 14 | palmerston
# Processing Record 47 of Set 14 | boyolangu
# Processing Record 48 of Set 14 | batemans bay
# Processing Record 49 of Set 14 | cordoba
# Processing Record 50 of Set 14 | mbanza-ngungu
# Processing Record 1 of Set 15 | mahibadhoo
# Processing Record 2 of Set 15 | kushmurun
# Processing Record 3 of Set 15 | venado tuerto
# Processing Record 4 of Set 15 | richards bay
# Processing Record 5 of Set 15 | dingle
# Processing Record 6 of Set 15 | samarai
# Processing Record 7 of Set 15 | nishihara
# Processing Record 8 of Set 15 | shenjiamen
# Processing Record 9 of Set 15 | riviere-au-renard
# Processing Record 10 of Set 15 | hattiesburg
# Processing Record 11 of Set 15 | aasiaat
# Processing Record 12 of Set 15 | kremenchuk
# Processing Record 13 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 14 of Set 15 | saurimo
# Processing Record 15 of Set 15 | capoterra
# Processing Record 16 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 15 | prince albert
# Processing Record 18 of Set 15 | mikolow
# Processing Record 19 of Set 15 | reo
# Processing Record 20 of Set 15 | yellandu
# Processing Record 21 of Set 15 | aboso
# Processing Record 22 of Set 15 | matagami
# Processing Record 23 of Set 15 | umm jarr
# City not found. Skipping...
# Processing Record 24 of Set 15 | toyooka
# Processing Record 25 of Set 15 | bilma
# Processing Record 26 of Set 15 | opuwo
# Processing Record 27 of Set 15 | novichikha
# Processing Record 28 of Set 15 | yelniki
# Processing Record 29 of Set 15 | baherden
# Processing Record 30 of Set 15 | endicott
# Processing Record 31 of Set 15 | camocim
# Processing Record 32 of Set 15 | palaikastron
# Processing Record 33 of Set 15 | bonthe
# Processing Record 34 of Set 15 | alyangula
# Processing Record 35 of Set 15 | pervomayskoye
# Processing Record 36 of Set 15 | kyaikkami
# Processing Record 37 of Set 15 | moncton
# Processing Record 38 of Set 15 | inuvik
# Processing Record 39 of Set 15 | san jose
# Processing Record 40 of Set 15 | alofi
# Processing Record 41 of Set 15 | vrangel
# Processing Record 42 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 43 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 44 of Set 15 | maningrida
# Processing Record 45 of Set 15 | san patricio
# Processing Record 46 of Set 15 | cermik
# Processing Record 47 of Set 15 | moose factory
# Processing Record 48 of Set 15 | wattegama
# Processing Record 49 of Set 15 | naze
# Processing Record 50 of Set 15 | newark
# Processing Record 1 of Set 16 | houma
# Processing Record 2 of Set 16 | becal
# Processing Record 3 of Set 16 | zhanaozen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# convert the array of dictionaries to a pandas dataframe

city_data_df = pd.DataFrame(city_data)

# Create new order
new_column_order = ["City", "Country", "Lat", "Lng", 
                   "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Busselton      AU -33.6500  115.3333     49.24        87           3
# 1           Talaya      RU  61.3833  152.7500     56.21        80          99
# 2             Aksu      CN  41.1231   80.2644     81.30        36          97
# 3          Mataura      NZ -46.1927  168.8643     28.87        94          17
# 4     Punta Arenas      CL -53.1500  -70.9167     39.31        60          40
# 5       Port Keats      AU -14.2500  129.5500     71.29        54           0
# 6            Pilar      BR  -9.5972  -35.9567     80.53        85          60
# 7          Hualmay      PE -11.0964  -77.6139     66.60        70          18
# 8          Grafton      US  42.2070  -71.6856     83.12        50           0
# 9  Mnogovershinnyy      RU  53.9353  139.9242     52.95        99         100
#
#    Wind Speed Current Description
# 0        9.95           clear sky
# 1        4.61     overcast clouds
# 2        7.83     overcast clouds
# 3        3.06          few clouds
# 4       11.50    scattered clouds
# 5        6.87           clear sky
# 6        7.16       broken clouds
# 7        9.48          few clouds
# 8        8.05           clear sky
# 9        2.26     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
